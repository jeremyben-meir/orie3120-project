# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
import statistics

# %% [markdown]
# # DATA CLEANSING

# %%
### SALES CSV #############################

sales = pd.read_csv("NYC_Citywide_Rolling_Calendar_Sales.csv")
print(sales.columns)

sales = sales[~sales['NEIGHBORHOOD'].isna()]
sales = sales[~sales['TOTAL UNITS'].isna()]
sales = sales[~sales['LAND SQUARE FEET'].isna()]
sales = sales[~sales['GROSS SQUARE FEET'].isna()]
sales = sales[~sales['YEAR BUILT'].isna()]
sales = sales[~sales['TAX CLASS AT TIME OF SALE'].isna()]
sales = sales[~sales['BUILDING CLASS AT TIME OF SALE'].isna()]
sales['SALE PRICE'] = sales['SALE PRICE'].str.replace(",","").astype(int)
sales = sales[~((sales['SALE PRICE'].isna())|(sales['SALE PRICE']<=0))]
sales["PRICE/UNIT"] = sales['SALE PRICE']/sales['TOTAL UNITS']
sales['NEIGHBORHOOD'] = sales['NEIGHBORHOOD'].apply(lambda n: n.replace(" (79-96)","").replace(" (59-79)",""))

### LISTINGS CSV ##########################

listings = pd.read_csv("listings_large.csv")
print(listings.columns)

listings['neighbourhood_cleansed'] = listings['neighbourhood_cleansed'].str.upper().str.replace(" DISTRICT","")
listings["price"] = listings['price'].str.replace("$","").str.replace(",","").astype(float)

listings = listings[~listings['neighbourhood_cleansed'].isna()]
listings = listings[~listings['number_of_reviews'].isna()]
listings = listings[~listings['bedrooms'].isna()]
listings = listings[~listings['beds'].isna()]
listings = listings[~listings['host_identity_verified'].isna()]
listings = listings[~listings['host_has_profile_pic'].isna()]
listings = listings[~listings['room_type'].isna()]
listings = listings[~listings['review_scores_rating'].isna()]
listings = listings[~listings['minimum_nights'].isna()]
listings = listings[~listings['host_is_superhost'].isna()]
listings = listings[listings['price']>0]

print(sales['NEIGHBORHOOD'].nunique())
print(listings['neighbourhood_cleansed'].nunique())
# Out:
# Index(['BOROUGH', 'NEIGHBORHOOD', 'BUILDING CLASS CATEGORY',
#        'TAX CLASS AT PRESENT', 'BLOCK', 'LOT', 'EASE-MENT',
#        'BUILDING CLASS AT PRESENT', 'ADDRESS', 'APARTMENT NUMBER', 'ZIP CODE',
#        'RESIDENTIAL UNITS', 'COMMERCIAL UNITS', 'TOTAL UNITS',
#        'LAND SQUARE FEET', 'GROSS SQUARE FEET', 'YEAR BUILT',
#        'TAX CLASS AT TIME OF SALE', 'BUILDING CLASS AT TIME OF SALE',
#        'SALE PRICE', 'SALE DATE'],
#       dtype='object')
# c:\Users\sunny\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (67) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'description',
#        'neighborhood_overview', 'picture_url', 'host_id', 'host_url',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')
# 246
# 220

# %% [markdown]
# # Q1

# %% [markdown]
# ### OPENDATA: neighborhood coef on sale price

# %%
X = pd.concat([
        pd.get_dummies(sales['NEIGHBORHOOD'], prefix="neighborhood", drop_first=True),
        sales['TOTAL UNITS'].astype(int),
        sales['LAND SQUARE FEET'].str.replace(",","").astype(int),
        sales['GROSS SQUARE FEET'].astype(int),
        sales['YEAR BUILT'].astype(int),
        pd.get_dummies(sales['TAX CLASS AT TIME OF SALE'], prefix="taxclass", drop_first=True),
        pd.get_dummies(sales['BUILDING CLASS AT TIME OF SALE'], prefix="bldgclass", drop_first=True),
    ],axis=1)

Y = sales['SALE PRICE']
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
model.summary()

neighborhood_params = model.params.loc[[val for val in model.params.index if "neighborhood_" in val]]
significant_params = neighborhood_params[neighborhood_params.index.isin(model.pvalues[model.pvalues<=.05].index)]
significant_params.sort_values()
# Out:
# neighborhood_DOWNTOWN-FULTON MALL        -3.163155e+07
# neighborhood_JAVITS CENTER               -1.698351e+07
# neighborhood_FLATIRON                    -1.651043e+07
# neighborhood_EAST VILLAGE                 7.524639e+06
# neighborhood_HUNTS POINT                  8.567422e+06
# neighborhood_WILLIAMSBURG-NORTH           8.661093e+06
# neighborhood_LOWER EAST SIDE              8.770358e+06
# neighborhood_CLINTON                      9.242175e+06
# neighborhood_TRIBECA                      9.265173e+06
# neighborhood_GREENWICH VILLAGE-WEST       9.900629e+06
# neighborhood_DOWNTOWN-METROTECH           1.003332e+07
# neighborhood_CHELSEA                      1.005147e+07
# neighborhood_UPPER WEST SIDE              1.069827e+07
# neighborhood_BROOKLYN HEIGHTS             1.310206e+07
# neighborhood_GREENWICH VILLAGE-CENTRAL    1.471068e+07
# neighborhood_FASHION                      1.484955e+07
# neighborhood_UPPER EAST SIDE              1.534424e+07
# neighborhood_FINANCIAL                    2.412859e+07
# neighborhood_SOHO                         2.439255e+07
# neighborhood_MIDTOWN WEST                 2.549634e+07
# neighborhood_MORNINGSIDE HEIGHTS          3.204254e+07
# neighborhood_DOWNTOWN-FULTON FERRY        3.527361e+07
# dtype: float64

# %% [markdown]
# ### AIRBNB: neighborhood coef on nightly price

# %%
X = pd.concat([
        pd.get_dummies(listings['neighbourhood_cleansed'], prefix="neighborhood", drop_first=True),
        listings['number_of_reviews'],
        listings['bedrooms'],
        listings['beds'],
        pd.get_dummies(listings['host_is_superhost'], prefix="host_is_superhost", drop_first=True),
        pd.get_dummies(listings['host_has_profile_pic'], prefix="host_has_profile_pic", drop_first=True),
        pd.get_dummies(listings['host_identity_verified'], prefix="host_identity_verified", drop_first=True),
        pd.get_dummies(listings['room_type'], prefix="room_type"),
        listings['review_scores_rating'],
        listings['minimum_nights'],
    ],axis=1)

Y = listings['price']
X = sm.add_constant(X)
model = sm.OLS(Y, X).fit()
model.summary()

neighborhood_params = model.params.loc[[val for val in model.params.index if "neighborhood_" in val]]
significant_params = neighborhood_params[neighborhood_params.index.isin(model.pvalues[model.pvalues<=.05].index)]
significant_params.sort_values(ascending=False)
# Out:
# neighborhood_TRIBECA              319.201512
# neighborhood_FLATIRON             317.434750
# neighborhood_JAMAICA ESTATES      306.806998
# neighborhood_MIDTOWN              238.171332
# neighborhood_SOHO                 211.993228
# neighborhood_THEATER              183.252825
# neighborhood_WEST VILLAGE         180.626892
# neighborhood_MURRAY HILL          177.864433
# neighborhood_GREENWICH VILLAGE    158.162670
# neighborhood_CHELSEA              152.023399
# neighborhood_FINANCIAL            127.144620
# neighborhood_EAST VILLAGE         116.708387
# neighborhood_HELL'S KITCHEN       114.932977
# neighborhood_UPPER WEST SIDE      107.829249
# neighborhood_GRAMERCY             104.208515
# neighborhood_NOLITA                98.565600
# neighborhood_LOWER EAST SIDE       97.259569
# neighborhood_UPPER EAST SIDE       92.555050
# dtype: float64

# %%
model.summary(
)
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.147
# Model:                            OLS   Adj. R-squared:                  0.139
# Method:                 Least Squares   F-statistic:                     18.63
# Date:                Sun, 15 May 2022   Prob (F-statistic):               0.00
# Time:                        17:35:58   Log-Likelihood:            -1.7437e+05
# No. Observations:               25149   AIC:                         3.492e+05
# Df Residuals:                   24918   BIC:                         3.511e+05
# Df Model:                         230
# Covariance Type:            nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# const                                    -26.4091     39.868     -0.662      0.508    -104.553      51.735
# neighborhood_ARDEN HEIGHTS                 6.8319    150.680      0.045      0.964    -288.510     302.174
# neighborhood_ARROCHAR                    -10.3923     94.172     -0.110      0.912    -194.976     174.191
# neighborhood_ARVERNE                      34.7907     52.406      0.664      0.507     -67.927     137.509
# neighborhood_ASTORIA                      18.2890     45.538      0.402      0.688     -70.968     107.546
# neighborhood_BATH BEACH                  -12.8699     76.393     -0.168      0.866    -162.605     136.865
# neighborhood_BATTERY PARK CITY            88.5279     65.901      1.343      0.179     -40.642     217.698
# neighborhood_BAY RIDGE                   -11.4116     51.155     -0.223      0.823    -111.678      88.855
# neighborhood_BAY TERRACE                 -33.0445    150.668     -0.219      0.826    -328.364     262.275
# neighborhood_BAYCHESTER                   44.4081     82.056      0.541      0.588    -116.426     205.242
# neighborhood_BAYSIDE                       8.5069     59.197      0.144      0.886    -107.522     124.536
# neighborhood_BAYSWATER                    -3.5508     82.081     -0.043      0.965    -164.435     157.333
# neighborhood_BEDFORD-STUYVESANT           16.3113     44.459      0.367      0.714     -70.832     103.455
# neighborhood_BELLE HARBOR                 47.4999     76.428      0.621      0.534    -102.304     197.304
# neighborhood_BELLEROSE                    21.8439    119.978      0.182      0.856    -213.320     257.008
# neighborhood_BELMONT                       3.8853     82.069      0.047      0.962    -156.975     164.746
# neighborhood_BENSONHURST                  -9.3073     56.062     -0.166      0.868    -119.193     100.578
# neighborhood_BERGEN BEACH                 -2.5910     90.406     -0.029      0.977    -179.793     174.611
# neighborhood_BOERUM HILL                  75.2765     51.230      1.469      0.142     -25.137     175.690
# neighborhood_BOROUGH PARK                  8.3696     54.043      0.155      0.877     -97.558     114.297
# neighborhood_BRIARWOOD                    -1.2189     66.606     -0.018      0.985    -131.771     129.333
# neighborhood_BRIGHTON BEACH                7.6769     62.391      0.123      0.902    -114.613     129.966
# neighborhood_BRONXDALE                     5.2251     78.083      0.067      0.947    -147.822     158.273
# neighborhood_BROOKLYN HEIGHTS            106.1773     55.136      1.926      0.054      -1.893     214.248
# neighborhood_BROWNSVILLE                   3.2319     54.041      0.060      0.952    -102.691     109.155
# neighborhood_BULL'S HEAD                 -39.2186    253.357     -0.155      0.877    -535.814     457.377
# neighborhood_BUSHWICK                     16.3055     44.746      0.364      0.716     -71.399     104.010
# neighborhood_CAMBRIA HEIGHTS              -6.0790     63.421     -0.096      0.924    -130.388     118.230
# neighborhood_CANARSIE                     43.1661     48.704      0.886      0.375     -52.296     138.628
# neighborhood_CARROLL GARDENS              59.5134     49.371      1.205      0.228     -37.257     156.284
# neighborhood_CASTLE HILL                 -15.0858    181.863     -0.083      0.934    -371.547     341.376
# neighborhood_CASTLETON CORNERS           -56.8174    132.339     -0.429      0.668    -316.209     202.575
# neighborhood_CHELSEA                     152.0234     45.614      3.333      0.001      62.618     241.429
# neighborhood_CHELSEA, STATEN ISLAND      -51.6882    253.387     -0.204      0.838    -548.342     444.966
# neighborhood_CHINATOWN                    77.9897     48.490      1.608      0.108     -17.054     173.033
# neighborhood_CITY ISLAND                  13.9093     94.160      0.148      0.883    -170.650     198.469
# neighborhood_CIVIC CENTER                 87.8149     74.904      1.172      0.241     -59.002     234.631
# neighborhood_CLAREMONT VILLAGE            -0.1479     76.417     -0.002      0.998    -149.930     149.634
# neighborhood_CLASON POINT                 -4.5622     66.632     -0.068      0.945    -135.166     126.041
# neighborhood_CLIFTON                      -1.6762     79.963     -0.021      0.983    -158.408     155.055
# neighborhood_CLINTON HILL                 55.3646     46.574      1.189      0.235     -35.924     146.653
# neighborhood_CO-OP CITY                    6.6840    181.858      0.037      0.971    -349.768     363.136
# neighborhood_COBBLE HILL                  91.7747     57.202      1.604      0.109     -20.345     203.895
# neighborhood_COLLEGE POINT                 6.1540     74.888      0.082      0.935    -140.631     152.939
# neighborhood_COLUMBIA ST                  73.9649     64.577      1.145      0.252     -52.610     200.540
# neighborhood_CONCORD                      13.1653    104.142      0.126      0.899    -190.959     217.289
# neighborhood_CONCOURSE                    17.9783     61.021      0.295      0.768    -101.627     137.583
# neighborhood_CONCOURSE VILLAGE           -30.0068     67.429     -0.445      0.656    -162.172     102.158
# neighborhood_CONEY ISLAND                 18.9092     87.222      0.217      0.828    -152.052     189.870
# neighborhood_CORONA                       -3.0213     54.939     -0.055      0.956    -110.706     104.663
# neighborhood_CROWN HEIGHTS                17.6476     44.932      0.393      0.694     -70.422     105.717
# neighborhood_CYPRESS HILLS                -7.4840     50.128     -0.149      0.881    -105.738      90.770
# neighborhood_DITMARS STEINWAY              9.3960     47.779      0.197      0.844     -84.254     103.046
# neighborhood_DONGAN HILLS                -92.9224    150.690     -0.617      0.537    -388.284     202.439
# neighborhood_DOUGLASTON                    8.3659    104.165      0.080      0.936    -195.804     212.536
# neighborhood_DOWNTOWN BROOKLYN           113.1926     63.411      1.785      0.074     -11.096     237.481
# neighborhood_DUMBO                       103.9292     78.088      1.331      0.183     -49.127     256.985
# neighborhood_DYKER HEIGHTS                -9.4146     87.217     -0.108      0.914    -180.364     161.535
# neighborhood_EAST ELMHURST                -8.6952     48.061     -0.181      0.856    -102.898      85.508
# neighborhood_EAST FLATBUSH                -0.9870     46.023     -0.021      0.983     -91.195      89.221
# neighborhood_EAST HARLEM                  42.8061     45.388      0.943      0.346     -46.157     131.770
# neighborhood_EAST MORRISANIA              36.8154     90.403      0.407      0.684    -140.379     214.010
# neighborhood_EAST NEW YORK               -20.8221     47.126     -0.442      0.659    -113.192      71.548
# neighborhood_EAST VILLAGE                116.7084     45.115      2.587      0.010      28.281     205.136
# neighborhood_EASTCHESTER                 -34.6854     90.456     -0.383      0.701    -211.985     142.614
# neighborhood_EDENWALD                      1.1243     79.954      0.014      0.989    -155.590     157.839
# neighborhood_EDGEMERE                     22.4398     87.213      0.257      0.797    -148.502     193.382
# neighborhood_ELMHURST                      7.1598     48.555      0.147      0.883     -88.011     102.331
# neighborhood_ELTINGVILLE                 -17.3962    253.363     -0.069      0.945    -514.002     479.210
# neighborhood_EMERSON HILL                 74.4366    150.791      0.494      0.622    -221.122     369.995
# neighborhood_FAR ROCKAWAY                -13.7319     64.591     -0.213      0.832    -140.334     112.871
# neighborhood_FIELDSTON                    27.3645    132.314      0.207      0.836    -231.978     286.707
# neighborhood_FINANCIAL                   127.1446     46.662      2.725      0.006      35.685     218.604
# neighborhood_FLATBUSH                     11.2441     46.191      0.243      0.808     -79.294     101.782
# neighborhood_FLATIRON                    317.4347     60.668      5.232      0.000     198.521     436.348
# neighborhood_FLATLANDS                    48.6095     54.322      0.895      0.371     -57.865     155.084
# neighborhood_FLUSHING                      4.4227     46.425      0.095      0.924     -86.573      95.419
# neighborhood_FORDHAM                     -27.8502     59.911     -0.465      0.642    -145.280      89.579
# neighborhood_FOREST HILLS                 52.0007     52.293      0.994      0.320     -50.496     154.498
# neighborhood_FORT GREENE                  62.1393     47.067      1.320      0.187     -30.115     154.394
# neighborhood_FORT HAMILTON                -3.4215     65.213     -0.052      0.958    -131.243     124.400
# neighborhood_FRESH MEADOWS                 3.5771     62.894      0.057      0.955    -119.699     126.853
# neighborhood_GERRITSEN BEACH              -6.1157    150.645     -0.041      0.968    -301.389     289.158
# neighborhood_GLEN OAKS                    21.1185    181.845      0.116      0.908    -335.309     377.546
# neighborhood_GLENDALE                    -15.9667     57.975     -0.275      0.783    -129.602      97.668
# neighborhood_GOWANUS                      66.6869     49.712      1.341      0.180     -30.751     164.125
# neighborhood_GRAMERCY                    104.2085     49.293      2.114      0.035       7.592     200.825
# neighborhood_GRANITEVILLE                  9.5431    253.380      0.038      0.970    -487.097     506.183
# neighborhood_GRANT CITY                    5.9977     84.526      0.071      0.943    -159.679     171.674
# neighborhood_GRAVESEND                    19.2767     59.522      0.324      0.746     -97.390     135.943
# neighborhood_GREAT KILLS                 -17.8885    132.324     -0.135      0.892    -277.252     241.475
# neighborhood_GREENPOINT                   58.7024     45.603      1.287      0.198     -30.682     148.087
# neighborhood_GREENWICH VILLAGE           158.1627     49.185      3.216      0.001      61.757     254.568
# neighborhood_GRYMES HILL                 -41.1339     98.640     -0.417      0.677    -234.473     152.206
# neighborhood_HARLEM                       34.6086     44.645      0.775      0.438     -52.899     122.116
# neighborhood_HELL'S KITCHEN              114.9330     44.935      2.558      0.011      26.857     203.009
# neighborhood_HIGHBRIDGE                    4.4013     79.965      0.055      0.956    -152.334     161.137
# neighborhood_HOLLIS                        3.0532     82.084      0.037      0.970    -157.836     163.943
# neighborhood_HOLLISWOOD                    1.4897    132.336      0.011      0.991    -257.896     260.875
# neighborhood_HOWARD BEACH                  6.9182     71.127      0.097      0.923    -132.494     146.331
# neighborhood_HOWLAND HOOK                -80.3739    181.850     -0.442      0.659    -436.811     276.064
# neighborhood_HUGUENOT                     43.5416    150.660      0.289      0.773    -251.761     338.844
# neighborhood_HUNTS POINT                   1.6615     70.107      0.024      0.981    -135.752     139.075
# neighborhood_INWOOD                       12.4624     49.155      0.254      0.800     -83.884     108.809
# neighborhood_JACKSON HEIGHTS               4.2254     48.211      0.088      0.930     -90.270      98.721
# neighborhood_JAMAICA                      -3.7648     47.427     -0.079      0.937     -96.724      89.194
# neighborhood_JAMAICA ESTATES             306.8070     71.164      4.311      0.000     167.321     446.293
# neighborhood_JAMAICA HILLS                10.8206    104.120      0.104      0.917    -193.261     214.902
# neighborhood_KENSINGTON                   26.8183     51.305      0.523      0.601     -73.743     127.380
# neighborhood_KEW GARDENS                   3.5782     61.959      0.058      0.954    -117.864     125.021
# neighborhood_KEW GARDENS HILLS            -4.3183     70.088     -0.062      0.951    -141.694     133.057
# neighborhood_KINGSBRIDGE                  17.6176     57.991      0.304      0.761     -96.048     131.283
# neighborhood_KIPS BAY                     89.2146     47.561      1.876      0.061      -4.007     182.436
# neighborhood_LAURELTON                     4.8525     58.865      0.082      0.934    -110.527     120.232
# neighborhood_LIGHTHOUSE HILL              36.8579    253.373      0.145      0.884    -459.768     533.484
# neighborhood_LITTLE ITALY                 76.9012     54.794      1.403      0.160     -30.498     184.301
# neighborhood_LITTLE NECK                 -34.3989    253.716     -0.136      0.892    -531.697     462.899
# neighborhood_LONG ISLAND CITY             75.2296     46.409      1.621      0.105     -15.735     166.194
# neighborhood_LONGWOOD                      4.9602     61.467      0.081      0.936    -115.518     125.439
# neighborhood_LOWER EAST SIDE              97.2596     45.362      2.144      0.032       8.347     186.172
# neighborhood_MANHATTAN BEACH             225.3913    119.980      1.879      0.060      -9.776     460.559
# neighborhood_MARBLE HILL                 -22.6997     98.623     -0.230      0.818    -216.008     170.608
# neighborhood_MARINERS HARBOR             -11.5635     90.482     -0.128      0.898    -188.914     165.787
# neighborhood_MASPETH                     -20.0627     52.200     -0.384      0.701    -122.377      82.252
# neighborhood_MELROSE                       8.1929     87.208      0.094      0.925    -162.739     179.125
# neighborhood_MIDDLE VILLAGE                6.7632     67.384      0.100      0.920    -125.314     138.840
# neighborhood_MIDLAND BEACH                -9.4228    111.010     -0.085      0.932    -227.008     208.163
# neighborhood_MIDTOWN                     238.1713     45.183      5.271      0.000     149.610     326.733
# neighborhood_MIDWOOD                       5.1559     54.040      0.095      0.924    -100.766     111.077
# neighborhood_MILL BASIN                  -25.8440    104.121     -0.248      0.804    -229.926     178.238
# neighborhood_MORNINGSIDE HEIGHTS          34.2064     49.101      0.697      0.486     -62.034     130.447
# neighborhood_MORRIS HEIGHTS               30.9001     79.965      0.386      0.699    -125.836     187.637
# neighborhood_MORRIS PARK                   4.6004     74.924      0.061      0.951    -142.256     151.457
# neighborhood_MORRISANIA                  -15.0355     84.463     -0.178      0.859    -180.587     150.516
# neighborhood_MOTT HAVEN                    0.1619     56.065      0.003      0.998    -109.729     110.053
# neighborhood_MOUNT EDEN                   12.7650    111.012      0.115      0.908    -204.825     230.355
# neighborhood_MOUNT HOPE                  -18.1949     66.618     -0.273      0.785    -148.770     112.380
# neighborhood_MURRAY HILL                 177.8644     48.535      3.665      0.000      82.734     272.995
# neighborhood_NAVY YARD                   141.9170    120.014      1.182      0.237     -93.318     377.152
# neighborhood_NEPONSIT                    200.5882    253.394      0.792      0.429    -296.079     697.256
# neighborhood_NEW BRIGHTON                  5.8994    104.103      0.057      0.955    -198.149     209.948
# neighborhood_NEW DORP                    -85.8697    253.397     -0.339      0.735    -582.542     410.803
# neighborhood_NEW DORP BEACH               -6.8011    132.313     -0.051      0.959    -266.143     252.541
# neighborhood_NEW SPRINGVILLE             -59.3727    120.002     -0.495      0.621    -294.584     175.839
# neighborhood_NOHO                        122.7295     63.982      1.918      0.055      -2.679     248.138
# neighborhood_NOLITA                       98.5656     48.826      2.019      0.044       2.864     194.267
# neighborhood_NORTH RIVERDALE             -30.4879     94.312     -0.323      0.746    -215.344     154.368
# neighborhood_NORWOOD                      21.8673     79.977      0.273      0.785    -134.893     178.627
# neighborhood_OAKWOOD                      -6.7292    104.161     -0.065      0.948    -210.891     197.432
# neighborhood_OLINVILLE                   -14.8957     87.221     -0.171      0.864    -185.855     156.063
# neighborhood_OZONE PARK                    0.7690     56.712      0.014      0.989    -110.390     111.928
# neighborhood_PARK SLOPE                   53.4985     47.025      1.138      0.255     -38.673     145.670
# neighborhood_PARKCHESTER                  21.9491     61.459      0.357      0.721     -98.514     142.412
# neighborhood_PELHAM BAY                   61.7732     98.639      0.626      0.531    -131.565     255.111
# neighborhood_PELHAM GARDENS              -25.4917     71.128     -0.358      0.720    -164.906     113.923
# neighborhood_PORT MORRIS                 -22.3831     68.294     -0.328      0.743    -156.243     111.477
# neighborhood_PORT RICHMOND               -17.1934    104.119     -0.165      0.869    -221.273     186.887
# neighborhood_PRINCE'S BAY                 13.5591    181.862      0.075      0.941    -342.902     370.020
# neighborhood_PROSPECT HEIGHTS             64.6706     48.139      1.343      0.179     -29.686     159.027
# neighborhood_PROSPECT-LEFFERTS GARDENS    10.8332     46.334      0.234      0.815     -79.983     101.650
# neighborhood_QUEENS VILLAGE               18.0108     55.670      0.324      0.746     -91.105     127.127
# neighborhood_RANDALL MANOR                -7.7211     98.621     -0.078      0.938    -201.024     185.582
# neighborhood_RED HOOK                     56.7129     57.978      0.978      0.328     -56.928     170.354
# neighborhood_REGO PARK                    12.8877     55.311      0.233      0.816     -95.526     121.301
# neighborhood_RICHMOND HILL                 4.2194     52.809      0.080      0.936     -99.290     107.729
# neighborhood_RICHMONDTOWN                 17.2467    181.861      0.095      0.924    -339.212     373.705
# neighborhood_RIDGEWOOD                     1.9927     47.383      0.042      0.966     -90.881      94.867
# neighborhood_RIVERDALE                    72.4801    111.005      0.653      0.514    -145.097     290.057
# neighborhood_ROCKAWAY BEACH                8.2189     52.814      0.156      0.876     -95.301     111.738
# neighborhood_ROOSEVELT ISLAND             71.2952     59.903      1.190      0.234     -46.118     188.709
# neighborhood_ROSEBANK                    -87.1742    120.000     -0.726      0.468    -322.382     148.034
# neighborhood_ROSEDALE                     -5.3695     54.323     -0.099      0.921    -111.845     101.106
# neighborhood_ROSSVILLE                    74.7327    253.605      0.295      0.768    -422.347     571.813
# neighborhood_SCHUYLERVILLE                 3.3445     76.409      0.044      0.965    -146.422     153.111
# neighborhood_SEA GATE                      6.3255    104.483      0.061      0.952    -198.467     211.118
# neighborhood_SHEEPSHEAD BAY              -10.0415     50.748     -0.198      0.843    -109.511      89.428
# neighborhood_SHORE ACRES                   4.4067    104.107      0.042      0.966    -199.648     208.462
# neighborhood_SILVER LAKE                 -50.3132    132.328     -0.380      0.704    -309.683     209.056
# neighborhood_SOHO                        211.9932     48.260      4.393      0.000     117.401     306.586
# neighborhood_SOUNDVIEW                    -1.0284     87.235     -0.012      0.991    -172.014     169.957
# neighborhood_SOUTH BEACH                  56.4184    253.385      0.223      0.824    -440.231     553.067
# neighborhood_SOUTH OZONE PARK             -3.9444     57.464     -0.069      0.945    -116.578     108.689
# neighborhood_SOUTH SLOPE                  24.4086     48.596      0.502      0.615     -70.843     119.661
# neighborhood_SPRINGFIELD GARDENS          -2.3307     50.080     -0.047      0.963    -100.491      95.829
# neighborhood_SPUYTEN DUYVIL              -36.9725    150.741     -0.245      0.806    -332.433     258.488
# neighborhood_ST. ALBANS                    6.7390     52.686      0.128      0.898     -96.529     110.007
# neighborhood_ST. GEORGE                  -22.5998     61.449     -0.368      0.713    -143.043      97.844
# neighborhood_STAPLETON                   -55.4125     78.090     -0.710      0.478    -208.474      97.649
# neighborhood_STUYVESANT TOWN              38.2435     65.904      0.580      0.562     -90.933     167.420
# neighborhood_SUNNYSIDE                    18.2404     47.459      0.384      0.701     -74.782     111.263
# neighborhood_SUNSET PARK                   9.2534     47.308      0.196      0.845     -83.473     101.979
# neighborhood_THEATER                     183.2528     49.581      3.696      0.000      86.071     280.435
# neighborhood_THROGS NECK                  -5.3620     74.884     -0.072      0.943    -152.140     141.416
# neighborhood_TOMPKINSVILLE                 8.3593     60.630      0.138      0.890    -110.480     127.198
# neighborhood_TOTTENVILLE                  -8.6415    181.860     -0.048      0.962    -365.097     347.814
# neighborhood_TREMONT                       0.7282     87.228      0.008      0.993    -170.243     171.700
# neighborhood_TRIBECA                     319.2015     53.272      5.992      0.000     214.785     423.618
# neighborhood_TWO BRIDGES                  68.6380     62.393      1.100      0.271     -53.656     190.932
# neighborhood_UNIONPORT                   -28.0316     90.417     -0.310      0.757    -205.255     149.191
# neighborhood_UNIVERSITY HEIGHTS           21.5494     82.070      0.263      0.793    -139.313     182.412
# neighborhood_UPPER EAST SIDE              92.5551     45.128      2.051      0.040       4.102     181.008
# neighborhood_UPPER WEST SIDE             107.8292     44.961      2.398      0.016      19.704     195.955
# neighborhood_VAN NEST                    -16.6727     87.213     -0.191      0.848    -187.615     154.269
# neighborhood_VINEGAR HILL                 74.1917     70.091      1.058      0.290     -63.192     211.575
# neighborhood_WAKEFIELD                    -0.6560     54.042     -0.012      0.990    -106.581     105.269
# neighborhood_WASHINGTON HEIGHTS           30.2760     45.749      0.662      0.508     -59.394     119.946
# neighborhood_WEST BRIGHTON                -7.2137     73.525     -0.098      0.922    -151.327     136.900
# neighborhood_WEST FARMS                   44.4938    132.335      0.336      0.737    -214.890     303.878
# neighborhood_WEST VILLAGE                180.6269     46.490      3.885      0.000      89.504     271.750
# neighborhood_WESTCHESTER SQUARE           21.9167    111.006      0.197      0.843    -195.662     239.496
# neighborhood_WESTERLEIGH                 -31.1166    253.381     -0.123      0.902    -527.759     465.526
# neighborhood_WHITESTONE                   10.5925     90.398      0.117      0.907    -166.594     187.778
# neighborhood_WILLIAMSBRIDGE               -3.3454     59.184     -0.057      0.955    -119.349     112.658
# neighborhood_WILLIAMSBURG                 64.3315     44.529      1.445      0.149     -22.948     151.611
# neighborhood_WILLOWBROOK                 -95.0786    253.464     -0.375      0.708    -591.882     401.725
# neighborhood_WINDSOR TERRACE               3.2216     52.493      0.061      0.951     -99.667     106.111
# neighborhood_WOODHAVEN                    -9.1031     55.132     -0.165      0.869    -117.164      98.958
# neighborhood_WOODLAWN                     18.5256    111.004      0.167      0.867    -199.048     236.099
# neighborhood_WOODROW                      10.8340    253.359      0.043      0.966    -485.764     507.432
# neighborhood_WOODSIDE                      0.9136     46.921      0.019      0.984     -91.054      92.881
# number_of_reviews                         -0.1339      0.028     -4.747      0.000      -0.189      -0.079
# bedrooms                                  73.9989      3.520     21.025      0.000      67.100      80.898
# beds                                      17.9986      2.182      8.248      0.000      13.721      22.276
# host_is_superhost_t                       10.2318      3.860      2.651      0.008       2.665      17.798
# host_has_profile_pic_t                     4.4063     19.719      0.223      0.823     -34.245      43.057
# host_identity_verified_t                   3.5344      4.379      0.807      0.420      -5.049      12.118
# room_type_Entire home/apt                  3.6586     11.474      0.319      0.750     -18.831      26.148
# room_type_Hotel room                      27.8141     21.448      1.297      0.195     -14.225      69.853
# room_type_Private room                   -43.0964     11.381     -3.787      0.000     -65.405     -20.788
# room_type_Shared room                    -14.7853     15.118     -0.978      0.328     -44.417      14.847
# review_scores_rating                       2.7949      2.065      1.354      0.176      -1.252       6.842
# minimum_nights                            -0.1837      0.065     -2.821      0.005      -0.311      -0.056
# ==============================================================================
# Omnibus:                    62008.821   Durbin-Watson:                   1.619
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        941436330.088
# Skew:                          26.522   Prob(JB):                         0.00
# Kurtosis:                     949.367   Cond. No.                     1.76e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.81e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# # Q2: Get compound sentiment of each review

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()
reviews = pd.read_csv("reviews_large.csv")
reviews = reviews[~reviews["comments"].isna()]
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\sunny\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
#add sentiment to reviews

global count
count = 0
print(len(reviews["comments"]))

def add_score(comment):
    try:
        global count
        count+=1
        if count%100000 == 0:
            print(count)
        return sia.polarity_scores(comment)["compound"]
    except:
        print(comment)

reviews["sentiment"] = reviews["comments"].apply(lambda comment: add_score(comment))
# Out:
# 927923
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000

# %%
# merge average sentiment into reviews

sentiment_df = reviews.groupby("listing_id").agg({"sentiment":"mean"})
listings_reviews = listings.merge(sentiment_df, how="inner", left_on='id', right_on='listing_id')

# %%
listings
# Out:
#                        id                                      listing_url  \
# 1                    5121                https://www.airbnb.com/rooms/5121
# 2                    5136                https://www.airbnb.com/rooms/5136
# 3                    5178                https://www.airbnb.com/rooms/5178
# 4                    5203                https://www.airbnb.com/rooms/5203
# 5                    5803                https://www.airbnb.com/rooms/5803
# ...                   ...                                              ...
# 37492  571894485688855296  https://www.airbnb.com/rooms/571894485688855296
# 37493  571916281271663365  https://www.airbnb.com/rooms/571916281271663365
# 37514  572366166013701340  https://www.airbnb.com/rooms/572366166013701340
# 37536  572733089973738908  https://www.airbnb.com/rooms/572733089973738908
# 37621  574716947639400817  https://www.airbnb.com/rooms/574716947639400817
#
#             scrape_id last_scraped  \
# 1      20220305031505   2022-03-05
# 2      20220305031505   2022-03-05
# 3      20220305031505   2022-03-05
# 4      20220305031505   2022-03-30
# 5      20220305031505   2022-03-05
# ...               ...          ...
# 37492  20220305031505   2022-03-05
# 37493  20220305031505   2022-03-05
# 37514  20220305031505   2022-03-05
# 37536  20220305031505   2022-03-05
# 37621  20220305031505   2022-03-05
#
#                                                     name  \
# 1                                        BlissArtsSpace!
# 2               Spacious Brooklyn Duplex, Patio + Garden
# 3                       Large Furnished Room Near B'way
# 4                     Cozy Clean Guest Room - Family Apt
# 5      Lovely Room 1 in BEST AREA; Legal Rental, Spot...
# ...                                                  ...
# 37492                               CHILLIN' ON CHAUNCEY
# 37493                                   CHA-CHA CHAUNCEY
# 37514                                  CHECKIN' CHAUNCEY
# 37536         Warm & Spacious House w/ patio and Parking
# 37621       DOUBLE BED + SPACIOUS && PRIME LOCATION ROOM
#
#                                              description  \
# 1      <b>The space</b><br />HELLO EVERYONE AND THANK...
# 2      We welcome you to stay in our lovely 2 br dupl...
# 3      Please don’t expect the luxury here just a bas...
# 4      Our best guests are seeking a safe, clean, spa...
# 5      Beautiful house, gorgeous garden, large patio,...
# ...                                                  ...
# 37492  QUEEN SIZED bed; PERFECT for COUPLES!<br /><br...
# 37493  QUEEN SIZED bed; PERFECT for COUPLES!<br /><br...
# 37514  QUEEN SIZED bed; PERFECT for COUPLES!<br /><br...
# 37536  Looking for a house to spend time with familie...
# 37621  Hey friends! <br /><br />Apartment type: Share...
#
#                                    neighborhood_overview  \
# 1                                                    NaN
# 2                                                    NaN
# 3        Theater district, many restaurants around here.
# 4      Our neighborhood is full of restaurants and ca...
# 5      Neighborhood is amazing!<br />Best subways to ...
# ...                                                  ...
# 37492                                                NaN
# 37493                                                NaN
# 37514                                                NaN
# 37536                                                NaN
# 37621                                                NaN
#
#                                              picture_url    host_id  \
# 1      https://a0.muscache.com/pictures/2090980c-b68e...       7356
# 2      https://a0.muscache.com/pictures/miso/Hosting-...       7378
# 3      https://a0.muscache.com/pictures/12065/f070997...       8967
# 4      https://a0.muscache.com/pictures/103776/b37157...       7490
# 5      https://a0.muscache.com/pictures/2884180/f19a1...       9744
# ...                                                  ...        ...
# 37492  https://a0.muscache.com/pictures/miso/Hosting-...  447103289
# 37493  https://a0.muscache.com/pictures/miso/Hosting-...  447103289
# 37514  https://a0.muscache.com/pictures/miso/Hosting-...  447103289
# 37536  https://a0.muscache.com/pictures/miso/Hosting-...  447327628
# 37621  https://a0.muscache.com/pictures/miso/Hosting-...  413204967
#
#                                           host_url  ...  \
# 1           https://www.airbnb.com/users/show/7356  ...
# 2           https://www.airbnb.com/users/show/7378  ...
# 3           https://www.airbnb.com/users/show/8967  ...
# 4           https://www.airbnb.com/users/show/7490  ...
# 5           https://www.airbnb.com/users/show/9744  ...
# ...                                            ...  ...
# 37492  https://www.airbnb.com/users/show/447103289  ...
# 37493  https://www.airbnb.com/users/show/447103289  ...
# 37514  https://www.airbnb.com/users/show/447103289  ...
# 37536  https://www.airbnb.com/users/show/447327628  ...
# 37621  https://www.airbnb.com/users/show/413204967  ...
#
#       review_scores_communication review_scores_location review_scores_value  \
# 1                            4.91                   4.47                4.52
# 2                            5.00                   4.50                5.00
# 3                            4.43                   4.87                4.37
# 4                            4.95                   4.94                4.92
# 5                            4.83                   4.87                4.74
# ...                           ...                    ...                 ...
# 37492                        5.00                   5.00                5.00
# 37493                        5.00                   5.00                5.00
# 37514                        5.00                   5.00                5.00
# 37536                        5.00                   5.00                5.00
# 37621                        5.00                   5.00                5.00
#
#       license instant_bookable calculated_host_listings_count  \
# 1         NaN                f                              2
# 2         NaN                f                              1
# 3         NaN                f                              1
# 4         NaN                f                              1
# 5         NaN                f                              3
# ...       ...              ...                            ...
# 37492     NaN                f                              3
# 37493     NaN                f                              3
# 37514     NaN                f                              3
# 37536     NaN                f                              1
# 37621     NaN                t                             28
#
#       calculated_host_listings_count_entire_homes  \
# 1                                               0
# 2                                               1
# 3                                               0
# 4                                               0
# 5                                               1
# ...                                           ...
# 37492                                           0
# 37493                                           0
# 37514                                           0
# 37536                                           1
# 37621                                           0
#
#       calculated_host_listings_count_private_rooms  \
# 1                                                2
# 2                                                0
# 3                                                1
# 4                                                1
# 5                                                2
# ...                                            ...
# 37492                                            3
# 37493                                            3
# 37514                                            3
# 37536                                            0
# 37621                                           28
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# 1                                               0              0.32
# 2                                               0              0.02
# 3                                               0              3.33
# 4                                               0              0.77
# 5                                               0              1.31
# ...                                           ...               ...
# 37492                                           0              3.00
# 37493                                           0              1.00
# 37514                                           0              1.00
# 37536                                           0              1.00
# 37621                                           0              1.00
#
# [25149 rows x 74 columns]

# %%
mean_sentiment = listings_reviews["sentiment"].mean()
listings_reviews['sentiment_binary'] = listings_reviews['sentiment'].apply(lambda s : 1 if s > mean_sentiment else 0)
listings_reviews['sq_beds'] = listings_reviews['beds']**2
X = pd.concat([
        listings_reviews['bedrooms'],
        listings_reviews['beds'],
        listings_reviews['sq_beds'],
        pd.get_dummies(listings_reviews['host_is_superhost'], prefix="host_is_superhost", drop_first=True),
        pd.get_dummies(listings_reviews['host_has_profile_pic'], prefix="host_has_profile_pic", drop_first=True),
        pd.get_dummies(listings_reviews['host_identity_verified'], prefix="host_identity_verified", drop_first=True),
        pd.get_dummies(listings_reviews['room_type'], prefix="room_type"),
        pd.get_dummies(listings_reviews['instant_bookable'], prefix="instant_bookable", drop_first=True),
    ],axis=1)

Y = listings_reviews['sentiment_binary']
X = sm.add_constant(X)
model = sm.Logit(Y, X).fit()
model.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.627929
#          Iterations: 35
# c:\Users\sunny\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:       sentiment_binary   No. Observations:                25147
# Model:                          Logit   Df Residuals:                    25136
# Method:                           MLE   Df Model:                           10
# Date:                Sun, 15 May 2022   Pseudo R-squ.:                 0.05228
# Time:                        17:34:13   Log-Likelihood:                -15791.
# converged:                      False   LL-Null:                       -16662.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                        -0.1126   7.54e+05  -1.49e-07      1.000   -1.48e+06    1.48e+06
# bedrooms                      0.0979      0.030      3.268      0.001       0.039       0.157
# beds                         -0.3080      0.033     -9.216      0.000      -0.373      -0.242
# sq_beds                       0.0179      0.004      4.550      0.000       0.010       0.026
# host_is_superhost_t           0.9169      0.033     27.453      0.000       0.851       0.982
# host_has_profile_pic_t        0.3468      0.161      2.150      0.032       0.031       0.663
# host_identity_verified_t      0.1238      0.036      3.406      0.001       0.053       0.195
# room_type_Entire home/apt     0.7171   7.54e+05   9.52e-07      1.000   -1.48e+06    1.48e+06
# room_type_Hotel room         -0.4878   7.54e+05  -6.47e-07      1.000   -1.48e+06    1.48e+06
# room_type_Private room        0.0082   7.54e+05   1.09e-08      1.000   -1.48e+06    1.48e+06
# room_type_Shared room        -0.3501   7.54e+05  -4.65e-07      1.000   -1.48e+06    1.48e+06
# instant_bookable_t           -0.4248      0.031    -13.555      0.000      -0.486      -0.363
# =============================================================================================
# """

# %%
X.columns[220:]
# Out:
# Index(['number_of_reviews', 'bedrooms', 'beds', 'host_is_superhost_t',
#        'host_has_profile_pic_t', 'host_identity_verified_t',
#        'room_type_Entire home/apt', 'room_type_Hotel room',
#        'room_type_Private room', 'room_type_Shared room',
#        'review_scores_rating', 'minimum_nights'],
#       dtype='object')

# %% [markdown]
# # Q3: Random Variables

# %%
reviews_summary = listings_reviews["review_scores_rating"].describe()
sentiment_summary = listings_reviews["sentiment"].describe()
print(reviews_summary)
print(sentiment_summary)
# Out:
# count    25147.000000
# mean         4.612306
# std          0.783162
# min          0.000000
# 25%          4.600000
# 50%          4.830000
# 75%          5.000000
# max          5.000000
# Name: review_scores_rating, dtype: float64
# count    25147.000000
# mean         0.716624
# std          0.239259
# min         -0.998800
# 25%          0.646651
# 50%          0.768500
# 75%          0.866024
# max          0.998700
# Name: sentiment, dtype: float64

# %%
N=100000
random_reviews = np.clip(np.random.normal(reviews_summary["mean"],reviews_summary["std"],N),0,5)
random_sentiment = np.clip(np.random.normal(sentiment_summary["mean"],sentiment_summary["std"],N),-1,1)

print(random_reviews)
print(random_sentiment)
# Out:
# [4.10302781 5.         3.64688616 ... 5.         2.94021168 3.93705951]
# [0.78533629 0.88707915 0.74589463 ... 0.56314032 0.66569228 0.20363901]

# %% [markdown]
# ### setting up analysis

# %%
X_Q3 = pd.concat([
        pd.get_dummies(listings_reviews['neighbourhood_cleansed'], prefix="neighborhood", drop_first=True),
        listings_reviews['number_of_reviews'],
        listings_reviews['bedrooms'],
        listings_reviews['beds'],
        pd.get_dummies(listings_reviews['host_is_superhost'], prefix="host_is_superhost", drop_first=True),
        pd.get_dummies(listings_reviews['host_has_profile_pic'], prefix="host_has_profile_pic", drop_first=True),
        pd.get_dummies(listings_reviews['host_identity_verified'], prefix="host_identity_verified", drop_first=True),
        pd.get_dummies(listings_reviews['room_type'], prefix="room_type"),
        listings_reviews['minimum_nights'],
        # listings_reviews['review_scores_rating'],
        listings_reviews["sentiment"]
    ],axis=1)

Y_Q3 = listings_reviews['price']
X_Q3 = sm.add_constant(X_Q3)
model_Q3 = sm.OLS(Y_Q3, X_Q3).fit()
model_Q3.summary()


# neighborhood_params = model.params.loc[[val for val in model.params.index if "neighborhood_" in val]]
# significant_params = neighborhood_params[neighborhood_params.index.isin(model.pvalues[model.pvalues<=.05].index)]
# significant_params.sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b86860b644b1> in <module>
# ----> 1 X_Q3 = pd.concat([
#       2         pd.get_dummies(listings_reviews['neighbourhood_cleansed'], prefix="neighborhood", drop_first=True),
#       3         listings_reviews['number_of_reviews'],
#       4         listings_reviews['bedrooms'],
#       5         listings_reviews['beds'],
#
# NameError: name 'pd' is not defined

# %%
print(len(model_Q3.params))
# Out:
# 233

# %%
print(list(model_Q3.params.index).index("neighborhood_FLATIRON"))
# Out:
# 74

# %%
print(list(model_Q3.params.index)[220:])
# Out:
# ['number_of_reviews', 'bedrooms', 'beds', 'host_is_superhost_t', 'host_has_profile_pic_t', 'host_identity_verified_t', 'room_type_Entire home/apt', 'room_type_Hotel room', 'room_type_Private room', 'room_type_Shared room', 'minimum_nights', 'review_scores_rating', 'sentiment_binary']

# %%
feature_vector = [0]*220
feature_vector[74] = 1 #flatiron location so 1
feature_vector[0] = 1 #constant 
avg_num_reviews = listings_reviews["number_of_reviews"].mean()
bedrooms = 3 # max is 15 which is way to high 
beds = 3
avg_minimum_nights = int(listings_reviews["minimum_nights"].mean())
# listings_reviews[""]
# listings_reviews[""]
# listings_reviews[""]
# listings_reviews[""]

non_neighborhood_features = [avg_num_reviews, bedrooms, beds, 1,1,1,1,0,0,0, avg_minimum_nights]
main_feature_vector = feature_vector + non_neighborhood_features

# %%
yhat_price_list = []
for i in range(len(random_reviews)):
  sent = random_sentiment[i] > mean_sentiment # turn to binary 
  final_features = main_feature_vector + [random_reviews[i]] + [sent]
  y = model_Q3.predict(final_features)[0]
  yhat_price_list.append(y)
  

print(statistics.mean(yhat_price_list))
# Out:
# 592.0358633334781

# %%
print(min(yhat_price_list))
# Out:
# 583.4575768128221

# %%
print(max(yhat_price_list))
# Out:
# 597.7618362974072

# %%
listings_reviews

rslt_df = listings_reviews[listings_reviews['neighbourhood_cleansed'] == "FLATIRON"]

# %%
rslt_df['price'].mean()
# Out:
# 446.25
