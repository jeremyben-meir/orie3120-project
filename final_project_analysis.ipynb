# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("listings.csv")
df
# Out:
# c:\Users\sunny\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#              id                                               name    host_id  \
# 0          2595                              Skylit Midtown Castle       2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...       4869
# 2          5121                                    BlissArtsSpace!       7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden       7378
# 4          5178                   Large Furnished Room Near B'way　       8967
# ...         ...                                                ...        ...
# 38272  53662330                HUGE PRIVATE ROOM, AWESOME LOCATION  100146245
# 38273  53662542   LARGE PRVT ROOM, QUIET RESIDENCE PERFECTLOCATION  100146245
# ...

# %%
rslt_df = df[df['neighbourhood'] == "Sunset Park"]

# %%
rslt_df
# Out:
#              id                                          name    host_id  \
# 3          5136      Spacious Brooklyn Duplex, Patio + Garden       7378
# 535      344092              Heavy Sun, Quiet, Arty 1 Bedroom    1745402
# 613      450578                                Serene Room...    9647066
# 704      528485       lovely private room in South Park Slope      17985
# 719      544039                   Luxury 2-bdrm w Piano & Gym    2674637
# ...         ...                                           ...        ...
# 37703  53433734                        Traveler's Cozy Studio   33612342
# 37884  53501342                         Nice room in Bayridge  433237033
# 38144  53607122   1-Bedroom Cozy & Convenient Brooklyn Escape    9117590
# 38155  53610853  Historic Row House Beauty w/ Backyard access    8619668
# 38241  53646539   Brooklyn cozy studio with spacious backyard   33067672
#
#          host_name neighbourhood_group neighbourhood   latitude  longitude  \
# ...

# %%
print(rslt_df['price'].mean())
print(rslt_df['price'].std())
# Out:
# 109.61837455830388
# 106.10386963037705

# %%
priv_df = rslt_df[rslt_df['room_type'] == "Private room"] 
priv_df
# Out:
#              id                                             name    host_id  \
# 613      450578                                   Serene Room...    9647066
# 704      528485          lovely private room in South Park Slope      17985
# 864      681599             1 Affordable and cozy in Sunset Park    1182180
# 1126     864981                 Cozy Room in Charming Brownstone    1650330
# 1195     940116               Bright Room in Historic Brownstone    1650330
# ...         ...                                              ...        ...
# 36613  52952850         Clean 1 bedroom in Brooklyn, Sunset Park  427142752
# 36924  53109730                                           121816  119692067
# 37483  53353569  Cozy Bedroom in Sunset Park with shared kitchen  224301575
# 37884  53501342                            Nice room in Bayridge  433237033
# 38144  53607122      1-Bedroom Cozy & Convenient Brooklyn Escape    9117590
#
# ...

# %%
print(priv_df['price'].mean())
print(priv_df['price'].std())
# Out:
# 67.92413793103448
# 78.09788042708372

# %%
print(priv_df['number_of_reviews'].mean())
print(priv_df['number_of_reviews'].std())
# Out:
# 18.875862068965517
# 33.034048671749424

# %%
priv_df['number_of_reviews'].corr(priv_df['price']*(365-priv_df['availability_365']))
# Out:
# -0.04970402460249881

# %%
priv_df.corr()
# Out:
#                                       id   host_id  latitude  longitude  \
# id                              1.000000  0.681615 -0.039650  -0.058329
# host_id                         0.681615  1.000000 -0.155414  -0.148091
# latitude                       -0.039650 -0.155414  1.000000   0.820888
# longitude                      -0.058329 -0.148091  0.820888   1.000000
# price                           0.098953  0.130306  0.040546  -0.001394
# minimum_nights                 -0.196720 -0.104176  0.123029   0.051412
# number_of_reviews              -0.186372 -0.058694  0.060845   0.145645
# reviews_per_month               0.343452  0.256796 -0.150840  -0.039656
# calculated_host_listings_count  0.297444  0.261429  0.047828  -0.022081
# availability_365                0.207313  0.223519 -0.059020  -0.036455
# number_of_reviews_ltm           0.306368  0.350377 -0.088963  -0.047987
#
#                                    price  minimum_nights  number_of_reviews  \
# ...
